# %% [markdown]
# <a href="https://colab.research.google.com/github/migueljoaod/dropwave/blob/master/ITC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Drop-Wave Function

# %% [markdown]
# # Implementando a função Drop-Wave
#
# É uma função multimodal e bidimensional
#
# f(x, y) = -(1 + cos(12*sqrt(x1^2+x2^2)) / 0.5*(x1^2+x2^2) + 2)

# %%
import math

def dropwavefcn(x, y):
  frac1 = 1 + math.cos(12 * math.sqrt(pow(x, 2) + pow(y, 2)))
  frac2 = 0.5*(pow(x, 2) + pow(y, 2)) + 2
  return (- frac1 / frac2)

# %% [markdown]
# # Gerando o gráfico

# %%
import numpy as np
import math
from mpl_toolkits.mplot3d import Axes3D  
# Axes3D import has side effects, it enables using projection='3d' in add_subplot
import matplotlib.pyplot as plt
import random
from IPython.display import Image
from matplotlib import cm



  

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
a = b = np.arange(-2.5, 2.5, 0.05)
A, B = np.meshgrid(a, b)
x = np.ravel(A)
y = np.ravel(B)
result = []
print(x)
for i in range(len(x)):
  result.append(dropwavefcn(x[i], y[i]))
zs = np.array(result)
Z = zs.reshape(X.shape)

ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.viridis)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

# Salva a figura em um arquivo
plt.savefig('grafico_de_linha')

plt.close('all')

# Exibe a imagem
Image('grafico_de_linha.png')
# Out:
# [-2.5  -2.45 -2.4  ...  2.35  2.4   2.45]

# %% [markdown]
# # Algorítmo de Busca Aleatoria

# %%
# Quantidade de tentativas de gerar uma nova solução
iteracoes = 1000

# listas com os dados para gerar o gráfico
func_objetivo = []
tentativas = []
valor_x = []

# contador de tentativas
i = 1

# Gera a solução inicial aleatoriamente respeitando os limites 
x = random.uniform(- 5.2, 5.2)
y = random.uniform(- 5.2, 5.2)

# calcula a qualidade da solucao
fo = dropwavefcn(x, y)

# salva os dados para geração do gráfico
func_objetivo.append(fo)
valor_x.append(x)
tentativas.append(0)


# enquanto houver tentativas
while i < iteracoes:
  
  # geracao de uma nova solucao aleatoriamente, respeitando os limites
  temp1 = random.uniform(- 5.2, 5.2)
  temp2 = random.uniform(- 5.2, 5.2)
  
  # Calcula a qualidade da solução gerada
  temp_fo = dropwavefcn(temp1, temp2)
  
  # se a nova solucao for melhor, atualiza
  if( temp_fo < fo ):
    fo = temp_fo
    x = temp1
    y = temp2
  
  
  # salva os dados para geração do gráfico
  func_objetivo.append(fo)
  tentativas.append(i)
  valor_x.append(x)
  
  # contabiliza a tentativa
  i = i + 1

#############################################
## Geracao do gráfico  
#############################################
# Importação da biblioteca MatplotLib

y = func_objetivo
x = tentativas

# Biblioteca matplotlib
import matplotlib
matplotlib.use('Agg')
# Gera os gráficos
import matplotlib.pyplot as plt

# Utilizado para cálculos
import numpy as np

# Utilizado para exibir as imagens
from IPython.display import Image

# Dados que serão utilizados


# Gera o gráfico de linhas
plt.plot(x, y )

# Coloca o título
plt.title("Desempenho da busca aleatoria")

plt.ylabel("Valor da funcao objetivo")
plt.xlabel("Iteracoes")

# Salva a figura em um arquivo
plt.savefig('grafico_de_linha')

plt.close('all')

# Exibe a imagem
Image('grafico_de_linha.png')

# %% [markdown]
# # Algorítmo por método Gradiente

# %%
#############################################
## Método de Gradiente 
#############################################

import random

# Quantidade de tentativas de gerar uma nova solução
iteracoes = 1000

# listas com os dados para gerar o gráfico
func_objetivo = []
tentativas = []
valor_x = []

# contador de tentativas
i = 1

# Gera a solução inicial aleatoriamente respeitando os limites 
x = random.uniform(- 5.2, 5.2)
y = random.uniform(- 5.2, 5.2)

# calcula a qualidade da solucao
fo = dropwavefcn(x, y)

# salva os dados para geração do gráfico
func_objetivo.append(fo)
valor_x.append(x)
tentativas.append(0)

# enquanto houver tentativas
while i < iteracoes:
  
  # geracao de uma nova solucao
  # aplicando uma pequena modificação
  temp1 = x + random.uniform(- 1, 1)
  temp2 = x + random.uniform(- 1, 1)  
  
  # Calcula a qualidade da solução gerada
  temp_fo = dropwavefcn(temp1, temp2)
  
  # se a nova solucao for melhor, atualiza
  if( temp_fo < fo ):
    fo = temp_fo
    x = temp1
    y = temp2

  
  # salva os dados para geração do gráfico
  func_objetivo.append(fo)
  tentativas.append(i)
  valor_x.append(x)
  
  # contabiliza a tentativa
  i = i + 1

#############################################
## Geracao do gráfico  
#############################################
# Importação da biblioteca MatplotLib

y = func_objetivo
x = tentativas

# Biblioteca matplotlib
import matplotlib
matplotlib.use('Agg')
# Gera os gráficos
import matplotlib.pyplot as plt

# Utilizado para cálculos
import numpy as np

# Utilizado para exibir as imagens
from IPython.display import Image

# Dados que serão utilizados


# Gera o gráfico de linhas
plt.plot(x, y )

# Coloca o título
plt.title("Desempenho da busca por método de gradiente")

plt.ylabel("Valor da funcao objetivo")
plt.xlabel("Iteracoes")

# Salva a figura em um arquivo
plt.savefig('grafico_de_linha')

plt.close('all')

# Exibe a imagem
Image('grafico_de_linha.png')
